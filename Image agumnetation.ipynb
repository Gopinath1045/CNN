# %%
import numpy as np
import pandas as pd

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten,\
 Conv2D, MaxPooling2D,BatchNormalization
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator , array_to_img, img_to_array, load_img
from tensorflow.keras.preprocessing import image
img_width, img_height = 150, 150

# %%
img=load_img("F:/gopimg/gopiimg.jpg")

# %%
#from PIL import Image
#img_data = np.random.random(size=(100, 100, 3))
#img = tf.keras.preprocessing.image.array_to_img(img_data)
#array = tf.keras.preprocessing.image.img_to_array(img)

# %%
img.size
# Out:
# (640, 640)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0xDED25E1640>

# %%
datagen=ImageDataGenerator(rotation_range=10,width_shift_range=0.2,zoom_range=0.2,
                            horizontal_flip=True,
                            shear_range=0.2,fill_mode='nearest')#different kind of images genarating
x=img_to_array(gopi)# to convert image into array 640 640 3 size image
x=x.reshape((1,) + x.shape) #to get multiple images 

#will save this genarated images in preview folder
#flow will generates the batches randomly and transforms images
i=0
for batch in datagen.flow(x, batch_size=1, save_to_dir='F:/gopimg/gops',save_prefix='gopi',save_format='jpg'):#saving the images in folder
    i+=1
    if i >20:
        break #to get only 20images

# %%
datagen
